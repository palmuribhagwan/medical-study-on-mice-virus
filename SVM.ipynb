# %% [markdown]
# ## Business Problem
#
# - The data shown here simulates a medical study in which mice infected with a virus were given various doses of two mediines and then chechked 2 weeks later to see if they were still infected

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('E:\\All Datasets\\mouse_viral_study.csv')
df
# Out:
#      Med_1_mL  Med_2_mL  Virus Present
# 0    6.508231  8.582531              0
# 1    4.126116  3.073459              1
# 2    6.427870  6.369758              0
# 3    3.672953  4.905215              1
# 4    1.580321  2.440562              1
# ..        ...       ...            ...
# 395  2.884122  3.271748              1
# 396  7.290855  9.488672              0
# 397  7.895325  8.272529              0
# 398  2.690592  2.674979              1
# 399  7.587821  9.473968              0
#
# [400 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Med_1_mL       400 non-null    float64
#  1   Med_2_mL       400 non-null    float64
#  2   Virus Present  400 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 9.5 KB

# %%
df['Virus Present'].value_counts()
# Out:
# 0    200
# 1    200
# Name: Virus Present, dtype: int64

# %% [markdown]
# ## EDA

# %%
sns.scatterplot(x='Med_1_mL',y='Med_2_mL',hue='Virus Present',data=df)
plt.show()

# %%
x=df.drop(columns='Virus Present')
y=df['Virus Present']

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear')
model.fit(x,y)
# Out:
# SVC(kernel='linear')

# %%
import bhag

# %%
from bhag import plot_svm
plot_svm(model,x,y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
pwd
# Out:
# 'C:\\Users\\admin\\1 Naresh IT\\Machine_Learning\\Classification'

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\admin\\1 Naresh IT\\Machine_Learning\\Classification'

# %%
os.chdir('C:\\Users\\admin\\Desktop\\module')


# now run is over

# %% [markdown]
# ## Hyper Parameters
#
# ### c
# - what is c?
#
# **regularization parameter. the strength of the regulrization is inversely proportional to C**

# %%
model = SVC(kernel='linear' , C=10)
model.fit(x,y)
plot_svm(model,x,y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='linear' , C=0.05)
model.fit(x,y)
plot_svm(model,x,y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='rbf' , C=1)
model.fit(x,y)
plot_svm(model,x,y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='sigmoid' )
model.fit(x,y)
plot_svm(model,x,y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
